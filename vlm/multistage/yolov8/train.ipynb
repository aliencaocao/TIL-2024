# %%
from ultralytics import YOLO
model = YOLO("runs/detect/yolov9c 0.99 0.769/weights/best.pt")  # load a pretrained model (recommended for training)

# %%
# Train the model
results = model.train(data="til.yaml", epochs=20, imgsz=640, single_cls=True, save=True, batch=12, patience=3, save_period=1, lr0=1e-3, momentum=0.9, optimizer='AdamW', cos_lr=True, box=7.5, cls=0.75, workers=1, plots=True, amp=True, resume=True)
# Out:
# Ultralytics YOLOv8.2.18  Python-3.9.13 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 12288MiB)
# ...

# %%
metrics = model.val()
metrics

# %%
onnx_model = YOLO("yolov8n.onnx")

# %%
from PIL import Image
im = Image.open('../../data/images/image_5106.jpg')

# %%
model.predict(im)
